# %%
import pyvww
import torch
import matplotlib.pyplot as plt

# %%
dataset = pyvww.pytorch.VisualWakeWordsClassification(root=".../coco/all", annFile=".../visualwakewords/annotations/instances_train.json")
# Out:
# loading annotations into memory...
# Done (t=0.93s)
# creating index...
# index created!

# %%
img, target = dataset[5]

# %%
display(img)
display(target)
# Out:
# <PIL.Image.Image image mode=RGB size=381x500 at 0x7F0FE6FA9050>
# 1

# %%
img_id = dataset.ids[5]
ann_ids = dataset.vww.getAnnIds(imgIds=img_id)
full_target = dataset.vww.loadAnns(ann_ids)
plt.imshow(img)
dataset.vww.showAnns(full_target)
